# %% [markdown]
# Split Date-Time to DATE and TIME columns

# %%
import pandas as pd
import numpy as np
import datetime as dt
import csv 
import matplotlib.pyplot as plt
import pytz

# %%
import os
cwd = os.getcwd()
cwd
# os.chdir('pvinhokkaidodatadistribution')
# C:\Users\Mhdella\Google Drive\Jupyter Folder\PV_Hokkaido_forecast_contest\
os.chdir('C:\\Users\\Mhdella\\Google Drive\\Jupyter Folder\\PV_Hokkaido_forecast_contest\\pvinhokkaidodatadistribution')
nwd=os.getcwd()
nwd
# Out:
# 'C:\\Users\\Mhdella\\Google Drive\\Jupyter Folder\\PV_Hokkaido_forecast_contest\\pvinhokkaidodatadistribution'

# %%
# file_name='Merg_Ens_Agg_42_44_mes17_18.csv'
# file_name='Merg_Ens_Agg_43_mes17_18.csv'
# file_name='Merg_Res_Comb_S1_S2_2018_tz_Jp.csv'
# file_name='Merg_Res_Comb_S1_S2_2017_tz_Jp.csv'
# file_name='Merg_Ens_Agg_42_44_mes16.csv'
file_name='Merg_Ens_mmaxmin_Agg_42_44_mes16_18.csv'


Data_Hokk=pd.read_csv(file_name,index_col=0) 

Data_Hokk.head()
# Out:
#                      S1[MW]  S2[MW]  solar[kW/m2]  temp[deg C]  \
# DATE_TIME
# 2016-01-01 09:00:00    54.7    78.4      0.159228         -1.2
# 2016-01-01 09:30:00   113.8    89.0      0.221269         -0.3
# 2016-01-01 10:00:00   115.9    97.3      0.231619         -0.5
# 2016-01-01 10:30:00   139.5   100.6      0.205909         -0.4
# 2016-01-01 11:00:00   125.7    96.8      0.277444         -0.2
#
#                      solar[kW/m2].1  temp[deg C].1  solar[kW/m2].2  \
# DATE_TIME
# 2016-01-01 09:00:00        0.276627            0.0        0.339371
# 2016-01-01 09:30:00        0.307764            0.1        0.297246
# 2016-01-01 10:00:00        0.354492            0.7        0.320564
# 2016-01-01 10:30:00        0.363168            0.8        0.306980
# 2016-01-01 11:00:00        0.358989            0.6        0.237579
#
#                      temp[deg C].2  solar[kW/m2].3  temp[deg C].3  \
# DATE_TIME
# 2016-01-01 09:00:00           -5.9        0.276318           -4.5
# ...

# %%
if 'Agg' in file_name:
    del Data_Hokk['time']
else:
    print('No additional time column need to be deleted')

# %%
Data_Hokk.index=pd.to_datetime(Data_Hokk.index)
Data_Hokk.index
Data_Hokk.index.date
Data_Hokk.insert(0, 'DATE', Data_Hokk.index.date)
Data_Hokk.insert(1, 'TIME', Data_Hokk.index.time)

Data_Hokk.head()
# Out:
#                            DATE      TIME  S1[MW]  S2[MW]  solar[kW/m2]  \
# DATE_TIME
# 2016-01-01 09:00:00  2016-01-01  09:00:00    54.7    78.4      0.159228
# 2016-01-01 09:30:00  2016-01-01  09:30:00   113.8    89.0      0.221269
# 2016-01-01 10:00:00  2016-01-01  10:00:00   115.9    97.3      0.231619
# 2016-01-01 10:30:00  2016-01-01  10:30:00   139.5   100.6      0.205909
# 2016-01-01 11:00:00  2016-01-01  11:00:00   125.7    96.8      0.277444
#
#                      temp[deg C]  solar[kW/m2].1  temp[deg C].1  \
# DATE_TIME
# 2016-01-01 09:00:00         -1.2        0.276627            0.0
# 2016-01-01 09:30:00         -0.3        0.307764            0.1
# 2016-01-01 10:00:00         -0.5        0.354492            0.7
# 2016-01-01 10:30:00         -0.4        0.363168            0.8
# 2016-01-01 11:00:00         -0.2        0.358989            0.6
#
#                      solar[kW/m2].2  temp[deg C].2      ...           t2m.2  \
# ...

# %%
print(len(Data_Hokk)) #number of rows
print(len(Data_Hokk.columns))  #number of columns
# Out:
# 35070
# 48

# %%
### Data_Hokk.to_csv(file_name, encoding='utf-8', index=False)
